# %%
s = "precedence"
print(len(s))
# Out:
# 10

# %%
s[0:12:2]
# Out:
# 'peeec'

# %%
s[0:12:-1]
# Out:
# ''

# %%
s[:12:4]
# Out:
# 'pec'

# %%
s[ : : -3]
# Out:
# 'eecp'

# %%
word = "recedence"
word
word.upper()
# Out:
# 'RECEDENCE'

# %%
#packages
s="packages"
s[0:70]
# Out:
# 'packages'

# %%
#package
s[0:7]
# Out:
# 'package'

# %%
#pack
s[0:4:]
# Out:
# 'p'

# %%
S="SOCIETY"
#tio
S[-2:-8:-2]
# Out:
# 'TIO'

# %%
S[5: :-2]6
+
# Out:
# 'TIO'
